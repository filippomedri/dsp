# %%
# %matplotlib inline

# %%
from pylab import *

# %%
import matplotlib as plt

# %%
x = linspace(0, 5, 10)
y = x ** 2

# %% [markdown]
# # Plot Example

# %%
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('Square Function')
show()
